# %%
salary = float(input("Enter your salary: "))
years_of_service = int(input("Enter your years of service: "))

if years_of_service > 5:
    bonus = salary * 0.05
    print(f"You are eligible for a 5% bonus.")
    print(f"Net bonus amount: {bonus:.2f}")
    print(f"Total with bonus: {salary + bonus:.2f}")
else:
    print("No bonus. Years of service must be more than 5 years.")
# Out:
# No bonus. Years of service must be more than 5 years.

# %%
age = int(input("Enter your age: "))

if age > 17:
    print("You are eligible for voting.")
else:
    print("You are not eligible for voting.")
# Out:
# You are eligible for voting.

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
    print(f"{num} is even.")
else:
    print(f"{num} is odd.")
# Out:
# 14 is even.

# %%
num = int(input("Enter a number: "))

if num % 7 == 0:
    print(f"{num} is divisible by 7.")
else:
    print(f"{num} is NOT divisible by 7.")
# Out:
# 1 is NOT divisible by 7.

# %%
num = int(input("Enter a number: "))

if num % 5 == 0:
    print("Hello")
else:
    print("Bye")
# Out:
# Hello

# %%
length = float(input("Enter the length: "))
breadth = float(input("Enter the breadth: "))

if length == breadth:
    print("It is a square.")
else:
    print("It is a rectangle.")
# Out:
# It is a rectangle.

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

if num1 > num2:
    print(f"{num1} is the greatest.")
elif num2 > num1:
    print(f"{num2} is the greatest.")
else:
    print("Both numbers are equal.")
# Out:
# 8 is the greatest.

# %%
marks = float(input("Enter your marks: "))

if marks < 25:
    grade = "F"
elif 25 <= marks < 45:
    grade = "E"
elif 45 <= marks < 50:
    grade = "D"
elif 50 <= marks < 60:
    grade = "C"
elif 60 <= marks < 80:
    grade = "B"
else:  # marks >= 80
    grade = "A"

print(f"Your grade is: {grade}")
# Out:
# Your grade is: A

# %%
age = int(input("Enter age: "))
gender = input("Enter gender M or F: ").upper()
marital_status = input("Enter marital status Y or N: ").upper()

if gender == "F":
    print("Place of service: Urban areas only")
elif gender == "M":
    if 20 <= age <= 40:
        print("Place of service: Anywhere")
    elif 40 < age <= 60:
        print("Place of service: Urban areas only")
    else:
        print("ERROR")
else:
    print("ERROR: Invalid gender input")
# Out:
# Place of service: Anywhere
